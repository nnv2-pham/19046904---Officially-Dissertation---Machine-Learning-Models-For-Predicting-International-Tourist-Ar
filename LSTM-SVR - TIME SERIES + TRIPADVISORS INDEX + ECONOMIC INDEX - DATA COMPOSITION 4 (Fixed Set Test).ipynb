# %%
y_pred=(894537.6286
,832707.0764
,889752.925
,976841.7398
,998650.6438
,1024230.192
,1110664.066
,1065599.773
,1195068.273
,857710.2867
,521624.1787
,341037.2099
,341036.4769
,341036.5049
,341036.4673
,341036.445
,341036.4433
,341036.4451
,341036.431
,341036.447
,341193.5528
,342254.1059
,343314.9716
,341648.4182
,346931.9861
,368623.774
,394808.6735
,414357.3559
,468688.7406
,536601.3785
,514247.047
,535757.7612
,582266.3115
,628221.6969
,697478.3559
,723807.9628
,707798.6083
,745708.3505
,783618.041
,821527.7145
,859437.4042)

y_test=(1468766
,1326668
,1185445
,1315792
,1512447
,1561274
,1618337
,1809580
,1710168
,1994125
,1242731
,449923
,0
,0
,0
,0
,0
,0
,0
,0
,0
,400
,3100
,5800
,1558
,15000
,70000
,136000
,185000
,320000
,486407
,431909
,484355
,596919
,707071
,871162
,932969
,895425
,984146
,916257
,975010)

# %%
from math import sqrt
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error 
from sklearn.metrics import mean_absolute_percentage_error

# %%
RMSE = np.sqrt(mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", RMSE)
# Out:
# Root Mean Squared Error: 393696.73461311194

# %%
MAE = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", MAE)
# Out:
# Mean Absolute Error: 331225.73180731706

# %%
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("Mean Absolute Percentage Error:", MAPE)
# Out:
# Mean Absolute Percentage Error: 3.371642064106616e+20

# %%
import matplotlib.pyplot as plt
x_ax = range(len(y_test))
plt.plot(x_ax, y_test, label="The Real Number of Tourist Arrivals")
plt.plot(x_ax, y_pred, label="The Predicted Number of Tourist Arrivals")
plt.title("Tourist Arrivals Test and Predicted Data \n LSTM-SVR  Time Series + Tripadvisors Index + Economic Index - Data Composition 4 (Fixed Set Test)")
plt.legend()
plt.show()
