# %%
y_pred=(891359.6631
,829530.1716
,885860.6588
,972868.1149
,993728.3163
,1019086.397
,1104488.457
,1059419.84
,1188064.599
,854483.4488
,519293.7537
,337228.9972
,330202.1114
,330442.2696
,330120.2074
,329929.0025
,329914.5284
,329929.2634
,329808.9962
,329946.2007
,330154.2433
,331076.9211
,332151.4912
,330873.2851
,336690.9832
,359723.0981
,388128.9664
,408566.4773
,462460.7329
,531599.4816
,509798.1185
,531453.3041
,579197.6028
,625383.3655
,694010.4789
,721082.4225
,705029.4416
,743123.9685
,780247.5521
,817371.2994
,854740.713)

y_test=(1468766
,1326668
,1185445
,1315792
,1512447
,1561274
,1618337
,1809580
,1710168
,1994125
,1242731
,449923
,0
,0
,0
,0
,0
,0
,0
,0
,0
,400
,3100
,5800
,1558
,15000
,70000
,136000
,185000
,320000
,486407
,431909
,484355
,596919
,707071
,871162
,932969
,895425
,984146
,916257
,975010)

# %%
from math import sqrt
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error 
from sklearn.metrics import mean_absolute_percentage_error

# %%
RMSE = np.sqrt(mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", RMSE)
# Out:
# Root Mean Squared Error: 392029.30751468067

# %%
MAE = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", MAE)
# Out:
# Mean Absolute Error: 328472.69164146343

# %%
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("Mean Absolute Percentage Error:", MAPE)
# Out:
# Mean Absolute Percentage Error: 3.262854440179589e+20

# %%
import matplotlib.pyplot as plt
x_ax = range(len(y_test))
plt.plot(x_ax, y_test, label="The Real Number of Tourist Arrivals")
plt.plot(x_ax, y_pred, label="The Predicted Number of Tourist Arrivals")
plt.title("Tourist Arrivals Test and Predicted Data \n LSTM-SVR  Time Series + Tripadvisors Index + Topic and Sentiment Intensity - Data Composition 4 (Fixed Set Test)")
plt.legend()
plt.show()
