# %%
y_pred=(887319.067
,824687.8107
,882476.6064
,970410.5042
,992340.2521
,1018001.252
,1104133.702
,1059346.552
,1187195.302
,850025.7796
,512792.031
,340975.8025
,340975.8261
,340975.8044
,340975.7918
,340975.7844
,340975.7803
,340975.7774
,340975.7742
,340975.7739
,341120.124
,342094.9482
,343070.5068
,341538.221
,346400.1613
,366480.7247
,390965.9204
,409410.7467
,461349.6107
,527477.4487
,505578.7484
,526648.8083
,572558.2182
,618323.7774
,687862.4675
,714429.4874
,698269.0192
,736565.5792
,774862.1454
,813158.7169
,851455.2929)
    
y_test=(1468766
,1326668
,1185445
,1315792
,1512447
,1561274
,1618337
,1809580
,1710168
,1994125
,1242731
,449923
,0
,0
,0
,0
,0
,0
,0
,0
,0
,400
,3100
,5800
,1558
,15000
,70000
,136000
,185000
,320000
,486407
,431909
,484355
,596919
,707071
,871162
,932969
,895425
,984146
,916257
,975010)

# %%
from math import sqrt
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error 
from sklearn.metrics import mean_absolute_percentage_error

# %%
RMSE = np.sqrt(mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", RMSE)
# Out:
# Root Mean Squared Error: 396475.5217446936

# %%
MAE = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", MAE)
# Out:
# Mean Absolute Error: 333057.68066585367

# %%
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("Mean Absolute Percentage Error:", MAPE)
# Out:
# Mean Absolute Percentage Error: 3.371028281914357e+20

# %%
import matplotlib.pyplot as plt
x_ax = range(len(y_test))
plt.plot(x_ax, y_test, label="The Real Number of Tourist Arrivals")
plt.plot(x_ax, y_pred, label="The Predicted Number of Tourist Arrivals")
plt.title("Tourist Arrivals Test and Predicted Data \n LSTM-SVR  Time Series + Economic Index - Data Composition 4 (Fixed Set Test)")
plt.legend()
plt.show()
