# %%
# Pandas is used for data manipulation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
import matplotlib.pyplot as plt

# %%
# Read in data and display fist 5 rows
df = pd.read_csv('TIME SERIES + TRIPADVISORS INDEX + TOPIC AND SENTIMENT INTENSITY + ECONOMIC INDEX - DATA COMPOSITION 1 (70-15-15).csv')
df1 = df.drop(['Class'], axis=1)
df1 = df1['Tourist Arrival']
df1 = np.array(df1).reshape(-1,1)
df1
plt.plot(df1)

# %%
scaler = MinMaxScaler(feature_range=(0,1))
df1 = scaler.fit_transform(df1)
df1.min()
# Out:
# 0.0

# %%
train_size = 134
validation_size = 26
test_size = 26

# %%
train = df1[0:134, :]
train.shape
# Out:
# (134, 1)

# %%
validation = df1[134:160, :]
validation.shape
# Out:
# (26, 1)

# %%
test = df1[160:186, :]
test.shape
# Out:
# (26, 1)

# %%
def get_data(df1, look_back):
    dataX, dataY = [], []
    for i in range (len(df1)-look_back-1):
        a = df1[i:(i+look_back),0]
        dataX.append(a)
        dataY.append(df1[i+look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
look_back = 1
x_train, y_train = get_data(train, look_back)

# %%
x_test, y_test = get_data(test, look_back)

# %%
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], 1)

# %%
from tensorflow.keras.optimizers import Adam

model = Sequential()
model.add(LSTM(24, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer =Adam(learning_rate=0.0005))
history = model.fit(x_train, y_train, epochs=50, batch_size=1)
model.summary()
# Out:
# Epoch 1/50
# 132/132 [==============================] - 4s 5ms/step - loss: 0.0697
# Epoch 2/50
# 132/132 [==============================] - 1s 6ms/step - loss: 0.0225
# Epoch 3/50
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0143
# Epoch 4/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0131
# Epoch 5/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0121
# Epoch 6/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0111
# Epoch 7/50
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0102
# Epoch 8/50
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0094
# Epoch 9/50
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0084
# Epoch 10/50
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0077
# Epoch 11/50
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0071
# Epoch 12/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0065
# Epoch 13/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0060
# Epoch 14/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0056
# Epoch 15/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0053
# Epoch 16/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0051
# Epoch 17/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0049
# Epoch 18/50
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0049
# Epoch 19/50
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0048
# Epoch 20/50
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0047
# Epoch 21/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0047
# Epoch 22/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0046
# Epoch 23/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0046
# Epoch 24/50
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0046
# Epoch 25/50
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0047
# Epoch 26/50
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0045
# Epoch 27/50
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0048
# Epoch 28/50
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0046
# Epoch 29/50
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0046
# Epoch 30/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0047
# Epoch 31/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0046
# Epoch 32/50
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0046
# Epoch 33/50
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0046
# Epoch 34/50
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0046
# Epoch 35/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0047
# Epoch 36/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0047
# Epoch 37/50
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0048
# Epoch 38/50
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0045
# Epoch 39/50
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0046
# Epoch 40/50
# 132/132 [==============================] - 1s 5ms/step - loss: 0.0046
# Epoch 41/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0047
# Epoch 42/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0046
# Epoch 43/50
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0046
# Epoch 44/50
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0046
# Epoch 45/50
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0046
# Epoch 46/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0046
# Epoch 47/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0045
# Epoch 48/50
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0046
# Epoch 49/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0045
# Epoch 50/50
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0046
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 24)                2496
#
#  dense_1 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 2,521
# Trainable params: 2,521
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_pred = model.predict(x_test)
# Out:
# 1/1 [==============================] - 0s 402ms/step

# %%
scaler.scale_
# Out:
# array([5.01473077e-07])

# %%
y_pred = scaler.inverse_transform(y_pred)

# %%
y_test = np.array(y_test)
y_test = y_test.reshape(-1,1)
y_test = scaler.inverse_transform(y_test)

# %%
from math import sqrt
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error 
from sklearn.metrics import mean_absolute_percentage_error

# %%
RMSE = np.sqrt(mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", RMSE)
# Out:
# Root Mean Squared Error: 94063.86488536317

# %%
MAE = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", MAE)
# Out:
# Mean Absolute Error: 85952.95247395833

# %%
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("Mean Absolute Percentage Error:", MAPE)
# Out:
# Mean Absolute Percentage Error: 9.84303333402127e+19

# %%
def SMAPE(y_test,y_pred):
    return 100/len(y_test) * np.sum(2 * np.abs(y_pred - y_test) / (np.abs(y_test) + np.abs(y_pred)))
result = SMAPE(y_test,y_pred)
print("SMAPE :", result)
# Out:
# SMAPE : 89.6172293292379

# %%
def RMSPE(y_test, y_pred):
    return np.sqrt(np.nanmean(np.square(((y_test - y_pred) / y_test))))*100
result1 = RMSPE(y_test,y_pred)
print("RMSPE :", result1)
# Out:
# RMSPE : inf
# /var/folders/w4/3f8pkphx2j78qktgvt5lpdvw0000gn/T/ipykernel_2290/2542154612.py:2: RuntimeWarning: divide by zero encountered in divide
#   return np.sqrt(np.nanmean(np.square(((y_test - y_pred) / y_test))))*100

# %%
x_ax = range(len(y_test))
plt.plot(x_ax, y_test, label="The Real Number of Tourist Arrivals")
plt.plot(x_ax, y_pred, label="The Predicted Number of Tourist Arrivals")
plt.title("Tourist Arrivals Test and Predicted Data \n LSTM - Time Series + Visitor Attention Index + Topic and Sentiment Intensity + Economic Index- Data Composition 1 (70-15-15)")
plt.legend()
plt.show()
