# %%
y_pred=(897392.9679
,834726.0931
,891642.3789
,978616.7296
,1000083.843
,1025497.587
,1111907.12
,1066530.018
,1196075.448
,861775.3602
,523079.7709
,339364.1002
,337446.7859
,337613.994
,337352.49
,337041.5355
,336771.8298
,336360.4464
,336092.1635
,335803.6121
,335845.7337
,336687.8822
,337457.8902
,339392.108
,344957.4931
,367010.1695
,393387.0464
,412764.5003
,467356.9164
,535515.4407
,512550.8788
,533984.1148
,580673.9784
,626830.9539
,696464.0296
,727482.7756
,710664.0069
,748234.6206
,785638.604
,823356.9553
,861058.5538)
    
y_test=(1468766
,1326668
,1185445
,1315792
,1512447
,1561274
,1618337
,1809580
,1710168
,1994125
,1242731
,449923
,0
,0
,0
,0
,0
,0
,0
,0
,0
,400
,3100
,5800
,1558
,15000
,70000
,136000
,185000
,320000
,486407
,431909
,484355
,596919
,707071
,871162
,932969
,895425
,984146
,916257
,975010)

# %%
from math import sqrt
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error 
from sklearn.metrics import mean_absolute_percentage_error

# %%
RMSE = np.sqrt(mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", RMSE)
# Out:
# Root Mean Squared Error: 391466.60847265826

# %%
MAE = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", MAE)
# Out:
# Mean Absolute Error: 328784.2683170732

# %%
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("Mean Absolute Percentage Error:", MAPE)
# Out:
# Mean Absolute Percentage Error: 3.328630905557903e+20

# %%
import matplotlib.pyplot as plt
x_ax = range(len(y_test))
plt.plot(x_ax, y_test, label="The Real Number of Tourist Arrivals")
plt.plot(x_ax, y_pred, label="The Predicted Number of Tourist Arrivals")
plt.title("Tourist Arrivals Test and Predicted Data \n LSTM-SVR  Time Series + Visitor Attention Index + Topic and Sentiment Intensity - Data Composition 4 (Fixed Set Test)")
plt.legend()
plt.show()
