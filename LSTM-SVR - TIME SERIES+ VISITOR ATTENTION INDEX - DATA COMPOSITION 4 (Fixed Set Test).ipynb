# %%
y_pred=(889148.9465
,826460.112
,884300.2737
,972419.4367
,994424.7087
,1020192.597
,1106851.479
,1061756.22
,1190709.411
,851816.3136
,513548.5936
,338371.5593
,338371.4663
,338371.456
,338371.3987
,338371.3445
,338371.3026
,338371.2546
,338371.2253
,338371.1977
,338520.0896
,339525.5173
,340531.5219
,338951.6934
,343964.3585
,364625.3333
,389732.6474
,408589.321
,461459.6615
,528376.688
,506258.5854
,527540.3884
,573801.3464
,619796.3822
,689522.2525
,716126.7213
,699945.29
,738284.6027
,776623.8965
,814963.2316
,853302.5671)
    
y_test=(1468766
,1326668
,1185445
,1315792
,1512447
,1561274
,1618337
,1809580
,1710168
,1994125
,1242731
,449923
,0
,0
,0
,0
,0
,0
,0
,0
,0
,400
,3100
,5800
,1558
,15000
,70000
,136000
,185000
,320000
,486407
,431909
,484355
,596919
,707071
,871162
,932969
,895425
,984146
,916257
,975010)

# %%
from math import sqrt
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error 
from sklearn.metrics import mean_absolute_percentage_error

# %%
RMSE = np.sqrt(mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", RMSE)
# Out:
# Root Mean Squared Error: 394826.4476619657

# %%
MAE = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", MAE)
# Out:
# Mean Absolute Error: 331481.0723707317

# %%
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("Mean Absolute Percentage Error:", MAPE)
# Out:
# Mean Absolute Percentage Error: 3.345285595282287e+20

# %%
import matplotlib.pyplot as plt
x_ax = range(len(y_test))
plt.plot(x_ax, y_test, label="The Real Number of Tourist Arrivals")
plt.plot(x_ax, y_pred, label="The Predicted Number of Tourist Arrivals")
plt.title("Tourist Arrivals Test and Predicted Data \n LSTM-SVR  Time Series  Visitor Attention Index - Data Composition 4 (Fixed Set Test)")
plt.legend()
plt.show()
