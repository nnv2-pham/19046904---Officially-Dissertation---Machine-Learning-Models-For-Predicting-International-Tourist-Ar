# %%
y_pred=(903718.4592
,842087.4425
,898953.0734
,985594.3997
,1007259.831
,1032655.019
,1118342.705
,1073690.844
,1201840.583
,867022.9467
,530276.7343
,347792.6813
,347792.6121
,347792.5986
,347792.5753
,347792.5597
,347792.5426
,347792.5305
,347792.5146
,347792.4978
,347951.9641
,349027.1606
,350102.5981
,348413.0367
,353768.8655
,375746.4159
,402252.7768
,422025.0603
,476905.9179
,545359.7771
,522844.6406
,544510.335
,591300.9887
,637465.3598
,706910.1415
,733272.3576
,717245.7099
,755183.4688
,793121.2699
,831059.0288
,860294.9938)
    
y_test=(1468766
,1326668
,1185445
,1315792
,1512447
,1561274
,1618337
,1809580
,1710168
,1994125
,1242731
,449923
,0
,0
,0
,0
,0
,0
,0
,0
,0
,400
,3100
,5800
,1558
,15000
,70000
,136000
,185000
,320000
,486407
,431909
,484355
,596919
,707071
,871162
,932969
,895425
,984146
,916257
,975010)

# %%
from math import sqrt
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error 
from sklearn.metrics import mean_absolute_percentage_error

# %%
RMSE = np.sqrt(mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", RMSE)
# Out:
# Root Mean Squared Error: 392547.91840795026

# %%
MAE = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", MAE)
# Out:
# Mean Absolute Error: 331330.28387560975

# %%
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("Mean Absolute Percentage Error:", MAPE)
# Out:
# Mean Absolute Percentage Error: 3.4384350402521406e+20

# %%
import matplotlib.pyplot as plt
x_ax = range(len(y_test))
plt.plot(x_ax, y_test, label="The Real Number of Tourist Arrivals")
plt.plot(x_ax, y_pred, label="The Predicted Number of Tourist Arrivals")
plt.title("Tourist Arrivals Test and Predicted Data \n LSTM-SVR  Time Series + Visitor Attention Index + Topic and Sentiment Intensity + Economic Index - Data Composition 4 (Fixed Set Test)")
plt.legend()
plt.show()
