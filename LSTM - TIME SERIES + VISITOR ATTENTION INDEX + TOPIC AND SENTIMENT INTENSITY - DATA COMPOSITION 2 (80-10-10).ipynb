# %%
# Pandas is used for data manipulation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
# Out:
# 2023-08-22 11:07:42.078547: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Read in data and display fist 5 rows
df = pd.read_csv('TIME SERIES + VISITOR ATTENTION INDEX +TOPIC AND SENTIMENT INTENSITY - DATA COMPOSITION 2 (80-10-10).csv')
df1 = df.drop(['Class'], axis=1)
df1 = df1['Tourist Arrival']
df1 = np.array(df1).reshape(-1,1)
df1
plt.plot(df1)

# %%
scaler = MinMaxScaler(feature_range=(0,1))
df1 = scaler.fit_transform(df1)
df1.min()
# Out:
# 0.0

# %%
train_size = 148
validation_size = 19
test_size = 19

# %%
train = df1[0:148, :]
train.shape
# Out:
# (148, 1)

# %%
validation = df1[148:167, :]
validation.shape
# Out:
# (19, 1)

# %%
test = df1[167:186, :]
test.shape
# Out:
# (19, 1)

# %%
def get_data(df1, look_back):
    dataX, dataY = [], []
    for i in range (len(df1)-look_back-1):
        a = df1[i:(i+look_back),0]
        dataX.append(a)
        dataY.append(df1[i+look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
look_back = 1
x_train, y_train = get_data(train, look_back)

# %%
x_test, y_test = get_data(test, look_back)

# %%
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], 1)

# %%
from tensorflow.keras.optimizers import Adam

model = Sequential()
model.add(LSTM(12, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer =Adam(learning_rate=0.0005))
history = model.fit(x_train, y_train, epochs=50, batch_size=1)
model.summary()
# Out:
# 2023-08-22 11:07:47.627354: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/50
# 146/146 [==============================] - 3s 2ms/step - loss: 0.1011
# Epoch 2/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0403
# Epoch 3/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0230
# Epoch 4/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0200
# Epoch 5/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0181
# Epoch 6/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0167
# Epoch 7/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0153
# Epoch 8/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0140
# Epoch 9/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0127
# Epoch 10/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0116
# Epoch 11/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0107
# Epoch 12/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0098
# Epoch 13/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 14/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0086
# Epoch 15/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 16/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0077
# Epoch 17/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0074
# Epoch 18/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0072
# Epoch 19/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0070
# Epoch 20/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0070
# Epoch 21/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0069
# Epoch 22/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0068
# Epoch 23/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0067
# Epoch 24/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0066
# Epoch 25/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0066
# Epoch 26/50
# 146/146 [==============================] - 1s 3ms/step - loss: 0.0067
# Epoch 27/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0067
# Epoch 28/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0067
# Epoch 29/50
# 146/146 [==============================] - 1s 3ms/step - loss: 0.0067
# Epoch 30/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0066
# Epoch 31/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0068
# Epoch 32/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0066
# Epoch 33/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0066
# Epoch 34/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0066
# Epoch 35/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0066
# Epoch 36/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0066
# Epoch 37/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0065
# Epoch 38/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0066
# Epoch 39/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0067
# Epoch 40/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0066
# Epoch 41/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0067
# Epoch 42/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0065
# Epoch 43/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0066
# Epoch 44/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0067
# Epoch 45/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0067
# Epoch 46/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0066
# Epoch 47/50
# 146/146 [==============================] - 0s 2ms/step - loss: 0.0066
# Epoch 48/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0066
# Epoch 49/50
# 146/146 [==============================] - 1s 4ms/step - loss: 0.0066
# Epoch 50/50
# 146/146 [==============================] - 0s 3ms/step - loss: 0.0067
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 12)                672
#
#  dense (Dense)               (None, 1)                 13
#
# =================================================================
# Total params: 685
# Trainable params: 685
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_pred = model.predict(x_test)
# Out:
# 1/1 [==============================] - 1s 919ms/step

# %%
scaler.scale_
# Out:
# array([5.01473077e-07])

# %%
y_pred = scaler.inverse_transform(y_pred)

# %%
y_test = np.array(y_test)
y_test = y_test.reshape(-1,1)
y_test = scaler.inverse_transform(y_test)

# %%
from math import sqrt
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error 
from sklearn.metrics import mean_absolute_percentage_error

# %%
RMSE = np.sqrt(mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", RMSE)
# Out:
# Root Mean Squared Error: 90352.28678699739

# %%
MAE = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", MAE)
# Out:
# Mean Absolute Error: 81406.30882352941

# %%
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("Mean Absolute Percentage Error:", MAPE)
# Out:
# Mean Absolute Percentage Error: 7.3933136721287225

# %%
def SMAPE(y_test,y_pred):
    return 100/len(y_test) * np.sum(2 * np.abs(y_pred - y_test) / (np.abs(y_test) + np.abs(y_pred)))
result = SMAPE(y_test,y_pred)
print("SMAPE :", result)
# Out:
# SMAPE : 47.154458855239845

# %%
def RMSPE(y_test, y_pred):
    return np.sqrt(np.nanmean(np.square(((y_test - y_pred) / y_test))))*100
result1 = RMSPE(y_test,y_pred)
print("RMSPE :", result1)
# Out:
# RMSPE : 2285.7922267952667

# %%
x_ax = range(len(y_test))
plt.plot(x_ax, y_test, label="The Real Number of Tourist Arrivals")
plt.plot(x_ax, y_pred, label="The Predicted Number of Tourist Arrivals")
plt.title("Tourist Arrivals Test and Predicted Data \n LSTM - Time Series + Visitor Attention Index + Topic and Sentiment Intensity - Data Composition 2 (80-10-10)")
plt.legend()
plt.show()
