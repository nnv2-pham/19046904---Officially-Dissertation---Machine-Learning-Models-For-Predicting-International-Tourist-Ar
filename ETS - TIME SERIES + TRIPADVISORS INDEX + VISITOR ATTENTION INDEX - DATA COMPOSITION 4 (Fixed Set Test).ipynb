# %%
# Pandas is used for data manipulation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read in data and display fist 5 rows
df = pd.read_csv('TIME SERIES + TRIPADVISORS INDEX + VISITOR ATTENTION INDEX + TOPIC AND SENTIMENT INTENSITY - DATA COMPOSITION 4 (Fixed Set Test).csv')
df.head(5)
# Out:
#         Month  Tourist Arrival  Number of Posts  Number of Comments  \
# 0  01/01/2008           399556              403                3049
# 1  01/02/2008           411032              357                3211
# 2  01/03/2008           414332              344                3153
# 3  01/04/2008           395900              338                3184
# 4  01/05/2008           366387              369                2964
#
#    Airbnb Vietnam  Vietnam restaurant  Shopping in Hanoi  \
# 0              11                  59                 32
# 1               0                  51                  0
# 2               0                  57                  7
# 3               0                  51                  6
# 4               0                  57                  0
#
#    Shopping in Ho Chi Minh   Vietnam tour    Skyscanner   ...   TOPIC 2  \
# 0                        8              58             7  ...  0.010894
# 1                        0              46             6  ...  0.010974
# 2                       24              58             6  ...  0.005849
# 3                        9              58             6  ...  0.013789
# 4                        7              57             6  ...  0.007257
#
#     TOPIC 3   TOPIC 4   TOPIC 5   TOPIC 6   TOPIC 7   TOPIC 8   TOPIC 9  \
# 0  0.889993  0.011228  0.010641  0.001710  0.014932  0.027566  0.014081
# 1  0.007221  0.006829  0.006410  0.005451  0.011673  0.014948  0.913561
# 2  0.006917  0.009097  0.007196  0.001611  0.007281  0.005533  0.014198
# 3  0.005867  0.911020  0.012191  0.001259  0.014063  0.019446  0.006807
# 4  0.010529  0.011619  0.014288  0.001458  0.015968  0.915464  0.010944
#
#    TOPIC 10  Class
# 0  0.010241  Train
# 1  0.013848  Train
# 2  0.934153  Train
# 3  0.008030  Train
# 4  0.003609  Train
#
# [5 rows x 36 columns]

# %%
x=df.drop('Tourist Arrival', axis=1)
y=df['Tourist Arrival']

# %%
train = df[df["Class"] == "Train"]
validation = df[df["Class"] == "Validation"]
test = df[df["Class"] == "Test"]
print(train.shape)
print(test.shape)
# Out:
# (134, 36)
# (40, 36)

# %%
train = train.drop(['Class'], axis=1)
validation = validation.drop(['Class'], axis=1)
test = test.drop(['Class'], axis=1)

# %%
target_column_train = ['Tourist Arrival']
predictors_train = list(set(list(train.columns))-set(target_column_train))

x_train = train[predictors_train].values
y_train = train[target_column_train].values


print(x_train.shape)
print(y_train.shape)
# Out:
# (134, 34)
# (134, 1)

# %%
target_column_validation = ['Tourist Arrival'] 
predictors_validation = list(set(list(validation.columns))-set(target_column_validation))

x_validation = validation[predictors_validation].values
y_validation = validation[target_column_validation].values

print(x_validation.shape)
print(y_validation.shape)
# Out:
# (12, 34)
# (12, 1)

# %%
target_column_test = ['Tourist Arrival'] 
predictors_test = list(set(list(test.columns))-set(target_column_test))

x_test = test[predictors_test].values
y_test = test[target_column_test].values

print(x_test.shape)
print(y_test.shape)
# Out:
# (40, 34)
# (40, 1)

# %%
train['Tourist Arrival'].plot(legend=True, label='TRAIN')
validation['Tourist Arrival'].plot(legend=True, label='VALIDATION')
test['Tourist Arrival'].plot(legend=True, label='TEST', figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
span = 12
alpha = 0.0001
model = SimpleExpSmoothing(train['Tourist Arrival']).fit(smoothing_level=alpha)
y_pred = model.forecast(40).rename('SES Forecast')

# %%
from math import sqrt
from sklearn.metrics import mean_absolute_error 
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_squared_error

# %%
RMSE = np.sqrt(mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", RMSE)
# Out:
# Root Mean Squared Error: 645671.0758497912

# %%
MAE = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", MAE)
# Out:
# Mean Absolute Error: 565083.453560712

# %%
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("Mean Absolute Percentage Error:", MAPE)
# Out:
# Mean Absolute Percentage Error: 5.667316418955165e+20

# %%
train['Tourist Arrival'].plot(legend=True, label='TRAIN')
validation['Tourist Arrival'].plot(legend=True, label='VALIDATION')
test['Tourist Arrival'].plot(legend=True, label='TEST', figsize=(12,8))
y_pred.plot(legend=True, label='PREDICTION')
plt.title("Tourist Arrivals Test and Predicted Data \n ETS - Time Series + Tripadvisors Index + Visitor Attention Index + Topic and Sentiment Intensity - Data Composition 4 (Fixed Set Test)")
# Out:
# Text(0.5, 1.0, 'Tourist Arrivals Test and Predicted Data \n ETS - Time Series + Tripadvisors Index + Visitor Attention Index + Topic and Sentiment Intensity - Data Composition 4 (Fixed Set Test)')
