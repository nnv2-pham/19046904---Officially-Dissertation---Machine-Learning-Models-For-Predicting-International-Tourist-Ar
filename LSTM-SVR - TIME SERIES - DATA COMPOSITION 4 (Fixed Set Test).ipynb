# %%
y_pred=(867044.182
,806170.6616
,862330.1599
,948214.7671
,969745.9779
,995010.0394
,1080446.9
,1035890.41
,1163951.918
,830774.9094
,501931.3466
,327567.3594
,327567.4366
,327567.3618
,327567.307
,327567.2866
,327567.2849
,327567.3144
,327567.3029
,327567.3144
,327718.075
,328735.8098
,329753.9082
,328154.6844
,333225.7016
,354065.9018
,379266.422
,398110.2716
,450610.9749
,516479.9071
,494769.7879
,515660.0994
,560909.72
,605724.9098
,673439.0482
,699232.8594
,683546.2366
,720706.8868
,757867.557
,795028.2616
,832188.9849)
    
y_test=(1468766
,1326668
,1185445
,1315792
,1512447
,1561274
,1618337
,1809580
,1710168
,1994125
,1242731
,449923
,0
,0
,0
,0
,0
,0
,0
,0
,0
,400
,3100
,5800
,1558
,15000
,70000
,136000
,185000
,320000
,486407
,431909
,484355
,596919
,707071
,871162
,932969
,895425
,984146
,916257
,975010)

# %%
from math import sqrt
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error 
from sklearn.metrics import mean_absolute_percentage_error

# %%
RMSE = np.sqrt(mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", RMSE)
# Out:
# Root Mean Squared Error: 401112.2715834253

# %%
MAE = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", MAE)
# Out:
# Mean Absolute Error: 334963.03210487805

# %%
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("Mean Absolute Percentage Error:", MAPE)
# Out:
# Mean Absolute Percentage Error: 3.2384799272325697e+20

# %%
import matplotlib.pyplot as plt
x_ax = range(len(y_test))
plt.plot(x_ax, y_test, label="The Real Number of Tourist Arrivals")
plt.plot(x_ax, y_pred, label="The Predicted Number of Tourist Arrivals")
plt.title("Tourist Arrivals Test and Predicted Data \n LSTM-SVR  Time Series - Data Composition 4 (Fixed Set Test)")
plt.legend()
plt.show()
