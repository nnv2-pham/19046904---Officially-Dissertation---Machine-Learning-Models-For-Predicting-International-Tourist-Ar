# %%
y_pred=(859268.9585
,799699.0754
,854661.5278
,938464.9116
,959432.4004
,984015.0938
,1067009.485
,1023752.081
,1147952.426
,823796.1029
,498896.7329
,323306.5925
,323306.6204
,323306.5929
,323306.5574
,323306.5294
,323306.5079
,323306.4841
,323306.4694
,323306.4551
,323459.5469
,324493.147
,325526.9856
,323903.0719
,329051.817
,350182.6505
,375674.3128
,394694.309
,447507.6595
,513425.0192
,491738.9385
,512606.7411
,557690.0272
,602191.521
,669175.0159
,694615.6286
,679148.5173
,715766.2961
,752384.0618
,789001.8478
,825619.6295)
    
y_test=(1468766
,1326668
,1185445
,1315792
,1512447
,1561274
,1618337
,1809580
,1710168
,1994125
,1242731
,449923
,0
,0
,0
,0
,0
,0
,0
,0
,0
,400
,3100
,5800
,1558
,15000
,70000
,136000
,185000
,320000
,486407
,431909
,484355
,596919
,707071
,871162
,932969
,895425
,984146
,916257
,975010)

# %%
from math import sqrt
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error 
from sklearn.metrics import mean_absolute_percentage_error

# %%
RMSE = np.sqrt(mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", RMSE)
# Out:
# Root Mean Squared Error: 403864.9536001692

# %%
MAE = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", MAE)
# Out:
# Mean Absolute Error: 336426.3311951219

# %%
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("Mean Absolute Percentage Error:", MAPE)
# Out:
# Mean Absolute Percentage Error: 3.196360374092591e+20

# %%
import matplotlib.pyplot as plt
x_ax = range(len(y_test))
plt.plot(x_ax, y_test, label="The Real Number of Tourist Arrivals")
plt.plot(x_ax, y_pred, label="The Predicted Number of Tourist Arrivals")
plt.title("Tourist Arrivals Test and Predicted Data \n LSTM-SVR  Time Series  Visitor Attention Index + Economic Index - Data Composition 4 (Fixed Set Test)")
plt.legend()
plt.show()
