# %%
# Pandas is used for data manipulation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
# Out:
# 2023-08-21 11:02:41.192413: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Read in data and display fist 5 rows
df = pd.read_csv('TIME SERIES + TOPIC AND SENTIMENT INTENSITY - DATA COMPOSITION 4 (Fixed Set Test).csv')
df1 = df.drop(['Class'], axis=1)
df1 = df1['Tourist Arrival']
df1 = np.array(df1).reshape(-1,1)
df1
plt.plot(df1)

# %%
scaler = MinMaxScaler(feature_range=(0,1))
df1 = scaler.fit_transform(df1)
df1.min()
# Out:
# 0.0

# %%
train_size = 133
validation_size = 13
test_size = 40

# %%
train = df1[0:133, :]
train.shape
# Out:
# (133, 1)

# %%
validation = df1[133:146, :]
validation.shape
# Out:
# (13, 1)

# %%
test = df1[146:186, :]
test.shape
# Out:
# (40, 1)

# %%
def get_data(df1, look_back):
    dataX, dataY = [], []
    for i in range (len(df1)-look_back-1):
        a = df1[i:(i+look_back),0]
        dataX.append(a)
        dataY.append(df1[i+look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
look_back = 1
x_train, y_train = get_data(train, look_back)

# %%
x_test, y_test = get_data(test, look_back)

# %%
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], 1)

# %%
from tensorflow.keras.optimizers import Adam

model = Sequential()
model.add(LSTM(24, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer =Adam(learning_rate=0.005))
history = model.fit(x_train, y_train, epochs=50, batch_size=1)
model.summary()
# Out:
# 2023-08-21 11:02:49.595950: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/50
# 131/131 [==============================] - 3s 3ms/step - loss: 0.0184
# Epoch 2/50
# 131/131 [==============================] - 0s 3ms/step - loss: 0.0107
# Epoch 3/50
# 131/131 [==============================] - 0s 3ms/step - loss: 0.0105
# Epoch 4/50
# 131/131 [==============================] - 0s 3ms/step - loss: 0.0085
# Epoch 5/50
# 131/131 [==============================] - 0s 3ms/step - loss: 0.0082
# Epoch 6/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0094
# Epoch 7/50
# 131/131 [==============================] - 0s 3ms/step - loss: 0.0095
# Epoch 8/50
# 131/131 [==============================] - 0s 3ms/step - loss: 0.0090
# Epoch 9/50
# 131/131 [==============================] - 0s 3ms/step - loss: 0.0087
# Epoch 10/50
# 131/131 [==============================] - 0s 3ms/step - loss: 0.0085
# Epoch 11/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0086
# Epoch 12/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0085
# Epoch 13/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0091
# Epoch 14/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 15/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0089
# Epoch 16/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0090
# Epoch 17/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0089
# Epoch 18/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0094
# Epoch 19/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0087
# Epoch 20/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 21/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0088
# Epoch 22/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0089
# Epoch 23/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0084
# Epoch 24/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0094
# Epoch 25/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 26/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0091
# Epoch 27/50
# 131/131 [==============================] - 0s 3ms/step - loss: 0.0091
# Epoch 28/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0086
# Epoch 29/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0085
# Epoch 30/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0086
# Epoch 31/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0081
# Epoch 32/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0091
# Epoch 33/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0080
# Epoch 34/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0088
# Epoch 35/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0086
# Epoch 36/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 37/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0091
# Epoch 38/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0087
# Epoch 39/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0085
# Epoch 40/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0084
# Epoch 41/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 42/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0088
# Epoch 43/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0080
# Epoch 44/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0090
# Epoch 45/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0086
# Epoch 46/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0084
# Epoch 47/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0079
# Epoch 48/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0084
# Epoch 49/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0089
# Epoch 50/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0083
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 24)                2496
#
#  dense (Dense)               (None, 1)                 25
#
# =================================================================
# Total params: 2,521
# Trainable params: 2,521
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_pred = model.predict(x_test)
# Out:
# 2/2 [==============================] - 0s 3ms/step

# %%
scaler.scale_
# Out:
# array([5.01473077e-07])

# %%
y_pred = scaler.inverse_transform(y_pred)

# %%
y_test = np.array(y_test)
y_test = y_test.reshape(-1,1)
y_test = scaler.inverse_transform(y_test)

# %%
from math import sqrt
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error 
from sklearn.metrics import mean_absolute_percentage_error

# %%
RMSE = np.sqrt(mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", RMSE)
# Out:
# Root Mean Squared Error: 221342.50623384517

# %%
MAE = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", MAE)
# Out:
# Mean Absolute Error: 161079.18503289475

# %%
MAPE = mean_absolute_percentage_error(y_test, y_pred)
print("Mean Absolute Percentage Error:", MAPE)
# Out:
# Mean Absolute Percentage Error: 1.4000957554746366e+20

# %%
def SMAPE(y_test,y_pred):
    return 100/len(y_test) * np.sum(2 * np.abs(y_pred - y_test) / (np.abs(y_test) + np.abs(y_pred)))
result = SMAPE(y_test,y_pred)
print("SMAPE :", result)
# Out:
# SMAPE : 84.45940411819102

# %%
def RMSPE(y_test, y_pred):
    return np.sqrt(np.nanmean(np.square(((y_test - y_pred) / y_test))))*100
result1 = RMSPE(y_test,y_pred)
print("RMSPE :", result1)
# Out:
# RMSPE : inf
# /var/folders/w4/3f8pkphx2j78qktgvt5lpdvw0000gn/T/ipykernel_15536/2542154612.py:2: RuntimeWarning: divide by zero encountered in divide
#   return np.sqrt(np.nanmean(np.square(((y_test - y_pred) / y_test))))*100

# %%
x_ax = range(len(y_test))
plt.plot(x_ax, y_test, label="The Real Number of Tourist Arrivals")
plt.plot(x_ax, y_pred, label="The Predicted Number of Tourist Arrivals")
plt.title("Tourist Arrivals Test and Predicted Data \n LSTM - Time Series - Data Composition 4 (Fixed Set Test)")
plt.legend()
plt.show()
